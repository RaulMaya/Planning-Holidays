# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func

# %%
# create engine to hawaii.sqlite
engine = create_engine("sqlite:///Resources/hawaii.sqlite")

# %%
# reflect an existing database into a new model
inspector =  inspect(engine)
# reflect the tables
inspector.get_table_names()
# Out:
# ['measurement', 'station']

# %%
# View all of the classes that automap found
Base = automap_base()

# %%
Base.prepare(engine, reflect = True)

# %%
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Save references to each table
Station = Base.classes.station
Measurement = Base.classes.measurement

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %%
first_row = session.query(Station).first()
first_row.__dict__
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState at 0x1b23d2caa90>,
#  'elevation': 3.0,
#  'name': 'WAIKIKI 717.2, HI US',
#  'id': 1,
#  'station': 'USC00519397',
#  'longitude': -157.8168,
#  'latitude': 21.2716}

# %%
first_row = session.query(Measurement).first()
first_row.__dict__
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState at 0x1b23d2d4160>,
#  'tobs': 65.0,
#  'date': '2010-01-01',
#  'id': 1,
#  'prcp': 0.08,
#  'station': 'USC00519397'}

# %% [markdown]
# # Exploratory Precipitation Analysis

# %%
# Find the most recent date in the data set.
date_list = []
recent_date = session.query(Measurement)
for date in recent_date:
    date_list.append(date.date)
most_recent_date = max(date_list)
print(f"The most recent date in the data set is {most_recent_date}")
# Out:
# The most recent date in the data set is 2017-08-23

# %%
general_measure = engine.execute("Select * From Measurement").fetchall()
len(general_measure)
# Out:
# 19550

# %%
# Design a query to retrieve the last 12 months of precipitation data and plot the results. 
last_twelve_months = engine.execute("Select * From Measurement Where date Between '2016-08-23' AND '2017-08-23'").fetchall()
len(last_twelve_months)
# Out:
# 2230

# %%
recent_precipitation = engine.execute("Select date, prcp From Measurement Where date Between '2016-08-23' AND '2017-08-23' ORDER BY date ASC").fetchall()
recent_precipitation
# Out:
# [('2016-08-23', 0.0),
#  ('2016-08-23', 0.15),
#  ('2016-08-23', 0.05),
#  ('2016-08-23', None),
#  ('2016-08-23', 0.02),
#  ('2016-08-23', 1.79),
#  ('2016-08-23', 0.7),
#  ('2016-08-24', 0.08),
#  ('2016-08-24', 2.15),
#  ('2016-08-24', 2.28),
#  ('2016-08-24', None),
#  ('2016-08-24', 1.22),
#  ('2016-08-24', 2.15),
#  ('2016-08-24', 1.45),
#  ('2016-08-25', 0.08),
#  ('2016-08-25', 0.08),
#  ('2016-08-25', 0.0),
#  ('2016-08-25', 0.0),
#  ('2016-08-25', 0.21),
#  ('2016-08-25', 0.06),
#  ('2016-08-25', 0.11),
#  ('2016-08-26', 0.0),
#  ('2016-08-26', 0.03),
#  ('2016-08-26', 0.02),
#  ('2016-08-26', 0.04),
#  ('2016-08-26', 0.0),
#  ('2016-08-26', 0.01),
#  ('2016-08-27', 0.0),
#  ('2016-08-27', 0.18),
#  ('2016-08-27', 0.02),
#  ('2016-08-27', 0.0),
#  ('2016-08-27', 0.12),
#  ('2016-08-27', None),
#  ('2016-08-28', 0.01),
#  ('2016-08-28', 0.14),
#  ('2016-08-28', 0.14),
#  ('2016-08-28', 0.14),
#  ('2016-08-28', 0.6),
#  ('2016-08-28', 2.07),
#  ('2016-08-29', 0.0),
# ...

# %%
results = session.query(Measurement.date, Measurement.prcp).\
    order_by(Measurement.date.desc()).all()
results
# Out:
# [('2017-08-23', 0.0),
#  ('2017-08-23', 0.0),
#  ('2017-08-23', 0.08),
#  ('2017-08-23', 0.45),
#  ('2017-08-22', 0.0),
#  ('2017-08-22', 0.0),
#  ('2017-08-22', 0.5),
#  ('2017-08-21', 0.0),
#  ('2017-08-21', 0.02),
#  ('2017-08-21', None),
#  ('2017-08-21', 0.56),
#  ('2017-08-20', 0.0),
#  ('2017-08-20', 0.01),
#  ('2017-08-20', None),
#  ('2017-08-19', 0.0),
#  ('2017-08-19', 0.0),
#  ('2017-08-19', None),
#  ('2017-08-19', 0.09),
#  ('2017-08-18', 0.0),
#  ('2017-08-18', 0.0),
#  ('2017-08-18', 0.06),
#  ('2017-08-18', None),
#  ('2017-08-17', 0.0),
#  ('2017-08-17', 0.05),
#  ('2017-08-17', 0.01),
#  ('2017-08-17', 0.13),
#  ('2017-08-16', 0.0),
#  ('2017-08-16', 0.07),
#  ('2017-08-16', 0.12),
#  ('2017-08-16', 0.42),
#  ('2017-08-15', 0.02),
#  ('2017-08-15', 0.0),
#  ('2017-08-15', 0.06),
#  ('2017-08-15', 0.32),
#  ('2017-08-15', 0.42),
#  ('2017-08-14', 0.0),
#  ('2017-08-14', 0.01),
#  ('2017-08-14', 0.08),
#  ('2017-08-14', 0.0),
#  ('2017-08-14', 0.22),
# ...

# %%
precipitation_df = pd.DataFrame(recent_precipitation, columns=['Date', 'Precipitation'])
precipitation_df = precipitation_df.dropna(how="any")
precipitation_df = precipitation_df.set_index("Date")
precipitation_df
# Out:
#             Precipitation
# Date
# 2016-08-23           0.00
# 2016-08-23           0.15
# 2016-08-23           0.05
# 2016-08-23           0.02
# 2016-08-23           1.79
# ...                   ...
# 2017-08-22           0.50
# 2017-08-23           0.00
# 2017-08-23           0.00
# 2017-08-23           0.08
# 2017-08-23           0.45
#
# [2021 rows x 1 columns]

# %%
gpby_precipitation = pd.DataFrame(recent_precipitation, columns=['Date', 'Precipitation'])
gpby_precipitation = precipitation_df.dropna(how="any")
gpby_precipitation = precipitation_df.groupby('Date').mean()
gpby_precipitation
# Out:
#             Precipitation
# Date
# 2016-08-23       0.451667
# 2016-08-24       1.555000
# 2016-08-25       0.077143
# 2016-08-26       0.016667
# 2016-08-27       0.064000
# ...                   ...
# 2017-08-19       0.030000
# 2017-08-20       0.005000
# 2017-08-21       0.193333
# 2017-08-22       0.166667
# 2017-08-23       0.132500
#
# [366 rows x 1 columns]

# %%
plt.figure(figsize=(100,55))

plt.title("Precipitation Plot")
plt.xlabel("Date")
plt.ylabel("Inches")

plt.xlim(0,len(gpby_precipitation["Precipitation"]))
plt.ylim(0, max(gpby_precipitation["Precipitation"]+0.5))
plt.bar(list(gpby_precipitation.index.values), gpby_precipitation["Precipitation"], color='blue',
        align ="center",width=0.5)

plt.savefig("Exploratory_Precipitation_Analysis/Precipitation_Plot_II.png")
plt.show()

# %%
plt.figure(figsize=(12,7.5))

plt.title("Precipitation Plot")
plt.xlabel("Date")
plt.ylabel("Inches")

plt.xlim(-0.5,len(gpby_precipitation["Precipitation"]))
plt.ylim(0, max(precipitation_df["Precipitation"]+0.5))
plt.bar(list(precipitation_df.index.values), precipitation_df["Precipitation"], color='blue',
        align ="center",width=1, label='Precipitation')

plt.xticks(np.arange(0, len(gpby_precipitation["Precipitation"])+1, 40),rotation=90)
plt.legend(loc='best')
plt.savefig("Exploratory_Precipitation_Analysis/Precipitation_Plot.png")
plt.show()

# %%
# Design a query to retrieve the last 12 months of precipitation data and plot the results. 
# Starting from the most recent data point in the database. 

# Calculate the date one year from the last date in data set.


# Perform a query to retrieve the data and precipitation scores


# Save the query results as a Pandas DataFrame and set the index to the date column


# Sort the dataframe by date


# Use Pandas Plotting with Matplotlib to plot the data


min(list(precipitation_df.index.values))
# Out:
# '2016-08-23'

# %%
# Use Pandas to calcualte the summary statistics for the precipitation data
precipitation_df.describe()
# Out:
#        Precipitation
# count    2021.000000
# mean        0.177279
# std         0.461190
# min         0.000000
# 25%         0.000000
# 50%         0.020000
# 75%         0.130000
# max         6.700000

# %% [markdown]
# # Exploratory Station Analysis

# %%
# Design a query to calculate the total number stations in the dataset
general_stations= engine.execute("Select * From Station").fetchall()
print(f"There is a total of {len(general_stations)} Stations in the dataset")
# Out:
# There is a total of 9 Stations in the dataset

# %%
first_row = session.query(Station).first()
first_row.__dict__
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState at 0x1b24026d1f0>,
#  'elevation': 3.0,
#  'name': 'WAIKIKI 717.2, HI US',
#  'id': 1,
#  'station': 'USC00519397',
#  'longitude': -157.8168,
#  'latitude': 21.2716}

# %%
# Design a query to find the most active stations (i.e. what stations have the most rows?)
# List the stations and the counts in descending order.
number_of_stations = engine.execute("Select date, station From Measurement").fetchall()
number_of_stations
# Out:
# [('2010-01-01', 'USC00519397'),
#  ('2010-01-02', 'USC00519397'),
#  ('2010-01-03', 'USC00519397'),
#  ('2010-01-04', 'USC00519397'),
#  ('2010-01-06', 'USC00519397'),
#  ('2010-01-07', 'USC00519397'),
#  ('2010-01-08', 'USC00519397'),
#  ('2010-01-09', 'USC00519397'),
#  ('2010-01-10', 'USC00519397'),
#  ('2010-01-11', 'USC00519397'),
#  ('2010-01-12', 'USC00519397'),
#  ('2010-01-14', 'USC00519397'),
#  ('2010-01-15', 'USC00519397'),
#  ('2010-01-16', 'USC00519397'),
#  ('2010-01-17', 'USC00519397'),
#  ('2010-01-18', 'USC00519397'),
#  ('2010-01-19', 'USC00519397'),
#  ('2010-01-20', 'USC00519397'),
#  ('2010-01-21', 'USC00519397'),
#  ('2010-01-22', 'USC00519397'),
#  ('2010-01-23', 'USC00519397'),
#  ('2010-01-24', 'USC00519397'),
#  ('2010-01-25', 'USC00519397'),
#  ('2010-01-26', 'USC00519397'),
#  ('2010-01-27', 'USC00519397'),
#  ('2010-01-28', 'USC00519397'),
#  ('2010-01-30', 'USC00519397'),
#  ('2010-01-31', 'USC00519397'),
#  ('2010-02-01', 'USC00519397'),
# ...

# %%
station_df = pd.DataFrame(number_of_stations, columns=['Date', 'Stations'])
stations_count = station_df.groupby('Stations').count()
stations_count = stations_count.rename(columns = {"Date":"Count"})
stations_count  = stations_count.sort_values(by='Count', ascending = False)
stations_count
# Out:
#              Count
# Stations
# USC00519281   2772
# USC00519397   2724
# USC00513117   2709
# USC00519523   2669
# USC00516128   2612
# USC00514830   2202
# USC00511918   1979
# USC00517948   1372
# USC00518838    511

# %%
#Most Active Station
mas = station_df['Stations'].mode()
mas = mas.to_list()
mas =  mas[0]
mas
# Out:
# 'USC00519281'

# %%
# Using the most active station id from the previous query, calculate the lowest, highest, and average temperature.
temperature = engine.execute("Select date, station, tobs From Measurement Where station = 'USC00519281' ").fetchall()
temperature
# Out:
# [('2010-01-01', 'USC00519281', 70.0),
#  ('2010-01-02', 'USC00519281', 62.0),
#  ('2010-01-03', 'USC00519281', 74.0),
#  ('2010-01-04', 'USC00519281', 75.0),
#  ('2010-01-05', 'USC00519281', 74.0),
#  ('2010-01-06', 'USC00519281', 76.0),
#  ('2010-01-07', 'USC00519281', 69.0),
#  ('2010-01-08', 'USC00519281', 66.0),
#  ('2010-01-09', 'USC00519281', 70.0),
#  ('2010-01-10', 'USC00519281', 75.0),
#  ('2010-01-11', 'USC00519281', 64.0),
#  ('2010-01-12', 'USC00519281', 60.0),
#  ('2010-01-13', 'USC00519281', 61.0),
#  ('2010-01-14', 'USC00519281', 68.0),
#  ('2010-01-15', 'USC00519281', 64.0),
#  ('2010-01-16', 'USC00519281', 66.0),
#  ('2010-01-17', 'USC00519281', 67.0),
#  ('2010-01-18', 'USC00519281', 70.0),
#  ('2010-01-19', 'USC00519281', 67.0),
#  ('2010-01-20', 'USC00519281', 67.0),
#  ('2010-01-21', 'USC00519281', 69.0),
#  ('2010-01-22', 'USC00519281', 60.0),
#  ('2010-01-23', 'USC00519281', 75.0),
#  ('2010-01-24', 'USC00519281', 75.0),
#  ('2010-01-25', 'USC00519281', 65.0),
# ...

# %%
tobs_df = pd.DataFrame(temperature, columns=['Date', 'Station', 'Temperature'])
lowest_temp = tobs_df['Temperature'].min()
highest_temp = tobs_df['Temperature'].max()
average_temp =tobs_df['Temperature'].mean()
print(f"The lowest temperature registered in station {mas} is {lowest_temp} F°")
print(f"The highest temperature registered in station {mas} is {highest_temp} F°")
print(f"The average temperature registered in station {mas} is {round(average_temp,2)} F°")
# Out:
# The lowest temperature registered in station USC00519281 is 54.0 F°
# The highest temperature registered in station USC00519281 is 85.0 F°
# The average temperature registered in station USC00519281 is 71.66 F°

# %%
filtered_temperature = engine.execute("Select date, station, tobs From Measurement Where station = 'USC00519281' ORDER BY date DESC").fetchall()
filtered_temperature
# Out:
# [('2017-08-18', 'USC00519281', 79.0),
#  ('2017-08-17', 'USC00519281', 76.0),
#  ('2017-08-16', 'USC00519281', 76.0),
#  ('2017-08-15', 'USC00519281', 77.0),
#  ('2017-08-14', 'USC00519281', 77.0),
#  ('2017-08-13', 'USC00519281', 77.0),
#  ('2017-08-06', 'USC00519281', 83.0),
#  ('2017-08-05', 'USC00519281', 82.0),
#  ('2017-08-04', 'USC00519281', 77.0),
#  ('2017-07-31', 'USC00519281', 76.0),
#  ('2017-07-30', 'USC00519281', 81.0),
#  ('2017-07-29', 'USC00519281', 82.0),
#  ('2017-07-28', 'USC00519281', 81.0),
#  ('2017-07-27', 'USC00519281', 76.0),
#  ('2017-07-26', 'USC00519281', 75.0),
#  ('2017-07-25', 'USC00519281', 77.0),
#  ('2017-07-24', 'USC00519281', 75.0),
#  ('2017-07-23', 'USC00519281', 82.0),
#  ('2017-07-22', 'USC00519281', 77.0),
#  ('2017-07-21', 'USC00519281', 77.0),
#  ('2017-07-20', 'USC00519281', 77.0),
#  ('2017-07-19', 'USC00519281', 76.0),
#  ('2017-07-18', 'USC00519281', 76.0),
#  ('2017-07-17', 'USC00519281', 76.0),
#  ('2017-07-16', 'USC00519281', 80.0),
# ...

# %%
filter_tobs_df = pd.DataFrame(filtered_temperature , columns=['Date', 'Station', 'Temperature'])
filter_tobs_df
# Out:
#             Date      Station  Temperature
# 0     2017-08-18  USC00519281         79.0
# 1     2017-08-17  USC00519281         76.0
# 2     2017-08-16  USC00519281         76.0
# 3     2017-08-15  USC00519281         77.0
# 4     2017-08-14  USC00519281         77.0
# ...          ...          ...          ...
# 2767  2010-01-05  USC00519281         74.0
# 2768  2010-01-04  USC00519281         75.0
# 2769  2010-01-03  USC00519281         74.0
# 2770  2010-01-02  USC00519281         62.0
# 2771  2010-01-01  USC00519281         70.0
#
# [2772 rows x 3 columns]

# %%
# Using the most active station id
# Query the last 12 months of temperature observation data for this station and plot the results as a histogram
hist_temperature = engine.execute("Select date, station, tobs From Measurement Where station = 'USC00519281' AND date Between '2016-08-23' AND '2017-08-23' ORDER BY date DESC ").fetchall()
hist_temperature
# Out:
# [('2017-08-18', 'USC00519281', 79.0),
#  ('2017-08-17', 'USC00519281', 76.0),
#  ('2017-08-16', 'USC00519281', 76.0),
#  ('2017-08-15', 'USC00519281', 77.0),
#  ('2017-08-14', 'USC00519281', 77.0),
#  ('2017-08-13', 'USC00519281', 77.0),
#  ('2017-08-06', 'USC00519281', 83.0),
#  ('2017-08-05', 'USC00519281', 82.0),
#  ('2017-08-04', 'USC00519281', 77.0),
#  ('2017-07-31', 'USC00519281', 76.0),
#  ('2017-07-30', 'USC00519281', 81.0),
#  ('2017-07-29', 'USC00519281', 82.0),
#  ('2017-07-28', 'USC00519281', 81.0),
#  ('2017-07-27', 'USC00519281', 76.0),
#  ('2017-07-26', 'USC00519281', 75.0),
#  ('2017-07-25', 'USC00519281', 77.0),
#  ('2017-07-24', 'USC00519281', 75.0),
#  ('2017-07-23', 'USC00519281', 82.0),
#  ('2017-07-22', 'USC00519281', 77.0),
#  ('2017-07-21', 'USC00519281', 77.0),
#  ('2017-07-20', 'USC00519281', 77.0),
#  ('2017-07-19', 'USC00519281', 76.0),
#  ('2017-07-18', 'USC00519281', 76.0),
#  ('2017-07-17', 'USC00519281', 76.0),
#  ('2017-07-16', 'USC00519281', 80.0),
# ...

# %%
hist_temperature_df = pd.DataFrame(hist_temperature, columns=['Date', 'Station', 'Temperature'])
hist_temperature_df
# Out:
#            Date      Station  Temperature
# 0    2017-08-18  USC00519281         79.0
# 1    2017-08-17  USC00519281         76.0
# 2    2017-08-16  USC00519281         76.0
# 3    2017-08-15  USC00519281         77.0
# 4    2017-08-14  USC00519281         77.0
# ..          ...          ...          ...
# 347  2016-08-27  USC00519281         75.0
# 348  2016-08-26  USC00519281         80.0
# 349  2016-08-25  USC00519281         80.0
# 350  2016-08-24  USC00519281         77.0
# 351  2016-08-23  USC00519281         77.0
#
# [352 rows x 3 columns]

# %%
plt.figure(figsize=(12,8))
plt.hist(hist_temperature_df["Temperature"],bins = 12, color = "blue", label = 'tobs')
plt.xlabel("Temperature")
plt.ylabel("Frecuency")
plt.legend(loc='best')
plt.savefig("Exploratory_Precipitation_Analysis/Tobs_Plot.png")
plt.show()

# %%
alt_result = session.query(Measurement.station).all()
alt_result
# Out:
# [('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
#  ('USC00519397'),
# ...

# %% [markdown]
# # Close session

# %%
def most_frequent(List):
    counter = 0
    num = List[0]
      
    for i in List:
        curr_frequency = List.count(i)
        if(curr_frequency> counter):
            counter = curr_frequency
            num = i
  
    return num
  

most_active_station = most_frequent(alt_result)
most_active_station
# Out:
# ('USC00519281')

# %%
most_active_station = list(most_active_station)
most_active_station = most_active_station[0]
most_active_station
# Out:
# 'USC00519281'

# %%
results = session.query(Measurement.date, Measurement.station,Measurement.tobs).filter(Measurement.station == most_active_station).all()
results
# Out:
# [('2010-01-01', 'USC00519281', 70.0),
#  ('2010-01-02', 'USC00519281', 62.0),
#  ('2010-01-03', 'USC00519281', 74.0),
#  ('2010-01-04', 'USC00519281', 75.0),
#  ('2010-01-05', 'USC00519281', 74.0),
#  ('2010-01-06', 'USC00519281', 76.0),
#  ('2010-01-07', 'USC00519281', 69.0),
#  ('2010-01-08', 'USC00519281', 66.0),
#  ('2010-01-09', 'USC00519281', 70.0),
#  ('2010-01-10', 'USC00519281', 75.0),
#  ('2010-01-11', 'USC00519281', 64.0),
#  ('2010-01-12', 'USC00519281', 60.0),
#  ('2010-01-13', 'USC00519281', 61.0),
#  ('2010-01-14', 'USC00519281', 68.0),
#  ('2010-01-15', 'USC00519281', 64.0),
#  ('2010-01-16', 'USC00519281', 66.0),
#  ('2010-01-17', 'USC00519281', 67.0),
#  ('2010-01-18', 'USC00519281', 70.0),
#  ('2010-01-19', 'USC00519281', 67.0),
#  ('2010-01-20', 'USC00519281', 67.0),
#  ('2010-01-21', 'USC00519281', 69.0),
#  ('2010-01-22', 'USC00519281', 60.0),
#  ('2010-01-23', 'USC00519281', 75.0),
#  ('2010-01-24', 'USC00519281', 75.0),
#  ('2010-01-25', 'USC00519281', 65.0),
# ...

# %%
most_recent_date = session.query(Measurement.date).order_by(Measurement.date.desc()).first()
most_recent_date= list(most_recent_date)
most_recent_date= most_recent_date[0]
most_recent_date = dt.datetime.strptime(most_recent_date, '%Y-%m-%d')
most_recent_date
# Out:
# datetime.datetime(2017, 8, 23, 0, 0)

# %%
year_ago = most_recent_date - dt.timedelta(days=365)
year_ago
# Out:
# datetime.datetime(2016, 8, 23, 0, 0)

# %%
results = session.query(Measurement.date, Measurement.station,Measurement.tobs).filter(Measurement.date <= most_recent_date).filter(Measurement.date >= year_ago).all()
results
# Out:
# [('2016-08-24', 'USC00519397', 79.0),
#  ('2016-08-25', 'USC00519397', 80.0),
#  ('2016-08-26', 'USC00519397', 79.0),
#  ('2016-08-27', 'USC00519397', 77.0),
#  ('2016-08-28', 'USC00519397', 78.0),
#  ('2016-08-29', 'USC00519397', 78.0),
#  ('2016-08-30', 'USC00519397', 79.0),
#  ('2016-08-31', 'USC00519397', 80.0),
#  ('2016-09-01', 'USC00519397', 81.0),
#  ('2016-09-02', 'USC00519397', 80.0),
#  ('2016-09-03', 'USC00519397', 79.0),
#  ('2016-09-04', 'USC00519397', 75.0),
#  ('2016-09-05', 'USC00519397', 79.0),
#  ('2016-09-06', 'USC00519397', 76.0),
#  ('2016-09-07', 'USC00519397', 76.0),
#  ('2016-09-08', 'USC00519397', 80.0),
#  ('2016-09-09', 'USC00519397', 79.0),
#  ('2016-09-10', 'USC00519397', 78.0),
#  ('2016-09-11', 'USC00519397', 76.0),
#  ('2016-09-12', 'USC00519397', 78.0),
#  ('2016-09-13', 'USC00519397', 78.0),
#  ('2016-09-14', 'USC00519397', 75.0),
#  ('2016-09-15', 'USC00519397', 79.0),
#  ('2016-09-16', 'USC00519397', 80.0),
#  ('2016-09-17', 'USC00519397', 79.0),
# ...

# %%
# Close Session
session.close()
